# %%
import numpy as np
import pandas as pd

from tqdm import tqdm 
from glob import glob
from skimage.io import imread
from skimage.color import rgb2gray
from skimage.measure import label, regionprops_table

from commons import binarize_image

# %%
def extract_props_from_image(mask):
    
    label_image = label(mask)

    feature_names = ['bbox_area',
                     'solidity',
                     'equivalent_diameter', 
                     'orientation',
                     'convex_area', 
                     'area',
                     'extent',
                     'eccentricity',
                     'major_axis_length',
                     'feret_diameter_max',
                     'perimeter',
                     'minor_axis_length']
    
    return pd.DataFrame(regionprops_table(label_image, properties=feature_names))

# %%
out = pd.DataFrame()

for index in tqdm(glob("data/masks/*")):
    
    try:

        image_gray = rgb2gray(imread(index))
        mask = binarize_image(image_gray)
        props = extract_props_from_image(mask)
        
        props['label'] = index.split('/')[-1]

        out = pd.concat([out, props], ignore_index=True)
    except Exception as e:
        print("Erro na imagem:", index, e)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 27/27 [01:16<00:00,  2.83s/it]

# %%
out
# Out:
#     bbox_area  solidity  equivalent_diameter  orientation  convex_area  \
# 0     2850729  0.930329          1546.333627    -1.562318      2018644
# 1     4860075  0.953191          2028.350299     1.541729      3389970
# 2     6563375  0.967800          2352.656763    -1.519653      4491812
# 3     4113401  0.937156          1862.425280     1.568393      2906938
# 4     3796888  0.959150          1825.033572     1.530045      2727375
# 5     1170324  0.942181          1048.896871     1.529494       917109
# 6      643857  0.967818           749.144347     1.523445       455436
# 7      927536  0.950450           933.347612     1.547423       719859
# 8     3750310  0.958539          1855.583431    -1.501295      2821248
# 9     3587128  0.965596          1801.975249    -1.565591      2641144
# 10    3795111  0.955904          1830.902209    -1.519917      2754265
# 11    3602860  0.966746          1772.086701     1.540118      2551217
# 12     610643  0.973320           725.832037    -1.475593       425115
# 13   10547344  0.963470          3053.785765    -1.556723      7602016
# 14    7223040  0.956107          2509.065195    -1.511072      5171390
# 15    7386379  0.951251          2470.983432     1.559301      5041206
# 16    3776792  0.956214          1839.964701     1.529981      2780697
# 17    5551968  0.955773          2183.263233     1.494157      3916943
# 18    3714822  0.965433          1837.204007     1.560389      2745885
# 19    4850391  0.946312          1998.095392     1.519854      3313506
# 20    6579952  0.928298          2366.478530    -1.536169      4738139
# 21    6445976  0.963302          2333.785471     1.552226      4440679
# 22    5295400  0.964530          2112.559661    -1.545900      3634061
# 23    5588154  0.912426          2152.778601    -1.562440      3989248
# 24    3964578  0.951235          1868.061957     1.534881      2881273
# 25    5264490  0.952203          2088.516753     1.482872      3597794
# 26    2095730  0.960036          1420.131417    -1.568148      1649907
#
#        area    extent  eccentricity  major_axis_length  feret_diameter_max  \
# 0   1878003  0.658780      0.921853        2531.940016         2708.014956
# 1   3231289  0.664864      0.911170        3196.000256         3425.843108
# 2   4347174  0.662338      0.912033        3722.922879         4046.791569
# 3   2724254  0.662287      0.968115        3779.721370         3959.977904
# 4   2615963  0.688976      0.908631        2846.925475         3024.139216
# 5    864083  0.738328      0.977688        2306.167462         2245.481908
# 6    440779  0.684591      0.943098        1309.058451         1367.422758
